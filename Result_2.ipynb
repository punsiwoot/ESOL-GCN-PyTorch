# %%
import matplotlib.pyplot as plt
import pickle

# %%
def merge_array(list):
    array = []
    for i in list:
        for j in i:
            array.append(j)
    return array
def training_result(result):
    print(f"lowest loss is {min(result)} at epoch : {result.index(min(result))+1}")

# %%
with open('save_variable\metric_s1_10000epoch.pkl', 'rb') as file: 
    # Call load method to deserialze 
    s1_p1 = pickle.load(file) 
with open('save_variable\metric_s2_10000epoch.pkl', 'rb') as file: 
    # Call load method to deserialze 
    s2_p1 = pickle.load(file) 
with open('save_variable\metric_s3_10000epoch.pkl', 'rb') as file: 
    #Call load method to deserialze 
    s3_p1 = pickle.load(file) 
with open('save_variable\metric_s4_10000epoch.pkl', 'rb') as file: 
    # Call load method to deserialze 
    s4_p1 = pickle.load(file) 
# with open('save_variable\metric_s1_5000epoch.pkl', 'rb') as file: 
#     # Call load method to deserialze 
#     s1_p2 = pickle.load(file) 
# with open('save_variable\metric_s2_5000epoch.pkl', 'rb') as file: 
#     # Call load method to deserialze 
#     s2_p2 = pickle.load(file) 
# with open('save_variable\metric_s3_5000epoch.pkl', 'rb') as file: 
#     # Call load method to deserialze 
#     s3_p2 = pickle.load(file) 
# with open('save_variable\metric_s4_5000epoch.pkl', 'rb') as file: 
#     # Call load method to deserialze 
#     s4_p2 = pickle.load(file) 
# with open('save_variable\metric_s1_7000epoch.pkl', 'rb') as file: 
#     # Call load method to deserialze 
#     s1_p3 = pickle.load(file) 
# with open('save_variable\metric_s2_7000epoch.pkl', 'rb') as file: 
#     # Call load method to deserialze 
#     s2_p3 = pickle.load(file) 
# with open('save_variable\metric_s3_7000epoch.pkl', 'rb') as file: 
#     # Call load method to deserialze 
#     s3_p3 = pickle.load(file) 
# with open('save_variable\metric_s4_7000epoch.pkl', 'rb') as file: 
#     # Call load method to deserialze 
#     s4_p3 = pickle.load(file)

# %%
#test result
with open('save_variable\metric_s1_3000epoch.pkl', 'rb') as file: 
    # Call load method to deserialze 
    test = pickle.load(file) 
testt = test['first_model']
plt.figure()
plt.plot(testt[1])
plt.show()

# %%
#first_model
first_model_p1 = s1_p1['first_model']
first_model_train_loss_p1 = first_model_p1[0]
first_model_valid_loss_p1 = first_model_p1[1]
# first_model_p2 = s1_p2['first_model']
# first_model_train_loss_p2 = first_model_p2[0]
# first_model_valid_loss_p2 = first_model_p2[1]
# first_model_p3 = s1_p3['first_model']
# first_model_train_loss_p3 = first_model_p3[0]
# first_model_valid_loss_p3 = first_model_p3[1]
first_model_train_loss = merge_array([first_model_train_loss_p1])#,first_model_train_loss_p2,first_model_train_loss_p3])
first_model_valid_loss = merge_array([first_model_valid_loss_p1])#,first_model_valid_loss_p2,first_model_valid_loss_p3])
plt.figure()
plt.plot(first_model_train_loss)
plt.show()
plt.figure()
plt.plot(first_model_valid_loss)
plt.show()
plt.figure()
plt.plot(first_model_valid_loss[6500:7500])
plt.show()
training_result(first_model_valid_loss)
# Out:
# lowest loss is 0.8781922310590744 at epoch : 6670

# %% [markdown]
# 0.8781932791074117

# %%
1.0007194479306538 in first_model_valid_loss
# Out:
# False

# %%
#Second_model
second_model_p1 = s1_p1['second_model']
second_model_train_loss_p1 = second_model_p1[0]
second_model_valid_loss_p1 = second_model_p1[1]
# second_model_p2 = s1_p2['second_model']
# second_model_train_loss_p2 = second_model_p2[0]
# second_model_valid_loss_p2 = second_model_p2[1]
# second_model_p3 = s1_p3['second_model']
# second_model_train_loss_p3 = second_model_p3[0]
# second_model_valid_loss_p3 = second_model_p3[1]
second_model_train_loss = merge_array([second_model_train_loss_p1])#,second_model_train_loss_p2,second_model_train_loss_p3])
second_model_valid_loss = merge_array([second_model_valid_loss_p1])#,second_model_valid_loss_p2,second_model_valid_loss_p3])
plt.figure()
plt.plot(second_model_train_loss)
plt.show()
plt.figure()
plt.plot(second_model_valid_loss)
plt.show()
plt.figure()
plt.plot(first_model_valid_loss[6200:6500])
plt.show()
# plt.figure()
# plt.plot(first_model_valid_loss[-1000:])
# plt.show()
training_result(second_model_valid_loss)
# Out:
# lowest loss is 1.037952075401942 at epoch : 4848

# %%
min(first_model_valid_loss[6200:6500]),min(first_model_valid_loss)
# Out:
# (0.8816647330919901, 0.8781922310590744)

# %%
#third_model
third_model_p1 = s1_p1['third_model']
third_model_train_loss_p1 = third_model_p1[0]
third_model_valid_loss_p1 = third_model_p1[1]
# third_model_p2 = s1_p2['third_model']
# third_model_train_loss_p2 = third_model_p2[0]
# third_model_valid_loss_p2 = third_model_p2[1]
# third_model_p3 = s1_p3['third_model']
# third_model_train_loss_p3 = third_model_p3[0]
# third_model_valid_loss_p3 = third_model_p3[1]
third_model_train_loss = merge_array([third_model_train_loss_p1])#,third_model_train_loss_p2,third_model_train_loss_p3])
third_model_valid_loss = merge_array([third_model_valid_loss_p1])#,third_model_valid_loss_p2,third_model_valid_loss_p3])
plt.figure()
plt.plot(third_model_train_loss)
plt.show()
plt.figure()
plt.plot(third_model_valid_loss)
plt.show()
plt.figure()
plt.plot(third_model_valid_loss[7500:10000])
plt.show()
training_result(third_model_valid_loss)
# Out:
# lowest loss is 0.7280292560656866 at epoch : 8890

# %%
#forth_model
forth_model_p1 = s1_p1['forth_model']
forth_model_train_loss_p1 = forth_model_p1[0]
forth_model_valid_loss_p1 = forth_model_p1[1]
# forth_model_p2 = s1_p2['forth_model']
# forth_model_train_loss_p2 = forth_model_p2[0]
# forth_model_valid_loss_p2 = forth_model_p2[1]
# forth_model_p3 = s1_p3['forth_model']
# forth_model_train_loss_p3 = forth_model_p3[0]
# forth_model_valid_loss_p3 = forth_model_p3[1]
forth_model_train_loss = merge_array([forth_model_train_loss_p1])#,forth_model_train_loss_p2,forth_model_train_loss_p3])
forth_model_valid_loss = merge_array([forth_model_valid_loss_p1])#,forth_model_valid_loss_p2,forth_model_valid_loss_p3])
plt.figure()
plt.plot(forth_model_train_loss)
plt.show()
plt.figure()
plt.plot(forth_model_valid_loss)
plt.show()
plt.figure()
plt.plot(forth_model_valid_loss[9000:10000])
plt.show()
training_result(forth_model_valid_loss)
# Out:
# lowest loss is 1.0607259372870128 at epoch : 9319

# %%
#fifth_model
fifth_model_p1 = s1_p1['fifth_model']
fifth_model_train_loss_p1 = fifth_model_p1[0]
fifth_model_valid_loss_p1 = fifth_model_p1[1]
# fifth_model_p2 = s1_p2['fifth_model']
# fifth_model_train_loss_p2 = fifth_model_p2[0]
# fifth_model_valid_loss_p2 = fifth_model_p2[1]
# fifth_model_p3 = s1_p3['fifth_model']
# fifth_model_train_loss_p3 = fifth_model_p3[0]
# fifth_model_valid_loss_p3 = fifth_model_p3[1]
fifth_model_train_loss = merge_array([fifth_model_train_loss_p1])#,fifth_model_train_loss_p2,fifth_model_train_loss_p3])
fifth_model_valid_loss = merge_array([fifth_model_valid_loss_p1])#,fifth_model_valid_loss_p2,fifth_model_valid_loss_p3])
plt.figure()
plt.plot(fifth_model_train_loss)
plt.show()
plt.figure()
plt.plot(fifth_model_valid_loss)
plt.show()
plt.figure()
plt.plot(fifth_model_valid_loss[9000:10000])
plt.show()
training_result(fifth_model_valid_loss)
# Out:
# lowest loss is 0.7704405585924784 at epoch : 9549

# %%
#sixth_model
sixth_model_p1 = s1_p1['sixth_model']
sixth_model_train_loss_p1 = sixth_model_p1[0]
sixth_model_valid_loss_p1 = sixth_model_p1[1]
# sixth_model_p2 = s1_p2['sixth_model']
# sixth_model_train_loss_p2 = sixth_model_p2[0]
# sixth_model_valid_loss_p2 = sixth_model_p2[1]
# sixth_model_p3 = s1_p3['sixth_model']
# sixth_model_train_loss_p3 = sixth_model_p3[0]
# sixth_model_valid_loss_p3 = sixth_model_p3[1]
sixth_model_train_loss = merge_array([sixth_model_train_loss_p1])#,sixth_model_train_loss_p2,sixth_model_train_loss_p3])
sixth_model_valid_loss = merge_array([sixth_model_valid_loss_p1])#,sixth_model_valid_loss_p2,sixth_model_valid_loss_p3])
plt.figure()
plt.plot(sixth_model_train_loss)
plt.show()
plt.figure()
plt.plot(sixth_model_valid_loss)
plt.show()
plt.figure()
plt.plot(sixth_model_valid_loss[4500:6500])
plt.show()
training_result(sixth_model_valid_loss)
# Out:
# lowest loss is 0.6979347368081411 at epoch : 4866

# %%
#seventh_model
seventh_model_p1 = s1_p1['seventh_model']
seventh_model_train_loss_p1 = seventh_model_p1[0]
seventh_model_valid_loss_p1 = seventh_model_p1[1]
# seventh_model_p2 = s1_p2['seventh_model']
# seventh_model_train_loss_p2 = seventh_model_p2[0]
# seventh_model_valid_loss_p2 = seventh_model_p2[1]
# seventh_model_p3 = s1_p3['seventh_model']
# seventh_model_train_loss_p3 = seventh_model_p3[0]
# seventh_model_valid_loss_p3 = seventh_model_p3[1]
seventh_model_train_loss = merge_array([seventh_model_train_loss_p1])#,seventh_model_train_loss_p2,seventh_model_train_loss_p3])
seventh_model_valid_loss = merge_array([seventh_model_valid_loss_p1])#,seventh_model_valid_loss_p2,seventh_model_valid_loss_p3])
plt.figure()
plt.plot(seventh_model_train_loss)
plt.show()
plt.figure()
plt.plot(seventh_model_valid_loss)
plt.show()
plt.figure()
plt.plot(seventh_model_valid_loss[5000:6000])
plt.show()
training_result(seventh_model_valid_loss)
# Out:
# lowest loss is 0.947960356871287 at epoch : 5227

# %%
#eighth_model
eighth_model_p1 = s1_p1['eighth_model']
eighth_model_train_loss_p1 = eighth_model_p1[0]
eighth_model_valid_loss_p1 = eighth_model_p1[1]
# eighth_model_p2 = s1_p2['eighth_model']
# eighth_model_train_loss_p2 = eighth_model_p2[0]
# eighth_model_valid_loss_p2 = eighth_model_p2[1]
# eighth_model_p3 = s1_p3['eighth_model']
# eighth_model_train_loss_p3 = eighth_model_p3[0]
# eighth_model_valid_loss_p3 = eighth_model_p3[1]
eighth_model_train_loss = merge_array([eighth_model_train_loss_p1])#,eighth_model_train_loss_p2,eighth_model_train_loss_p3])
eighth_model_valid_loss = merge_array([eighth_model_valid_loss_p1])#,eighth_model_valid_loss_p2,eighth_model_valid_loss_p3])
plt.figure()
plt.plot(eighth_model_train_loss)
plt.show()
plt.figure()
plt.plot(eighth_model_valid_loss)
plt.show()
plt.figure()
plt.plot(eighth_model_valid_loss[7000:10000])
plt.show()
training_result(eighth_model_valid_loss)
# Out:
# lowest loss is 1.0135449866453807 at epoch : 8438

# %%
#ninth_model
ninth_model_p1 = s1_p1['ninth_model']
ninth_model_train_loss_p1 = ninth_model_p1[0]
ninth_model_valid_loss_p1 = ninth_model_p1[1]
# ninth_model_p2 = s1_p2['ninth_model']
# ninth_model_train_loss_p2 = ninth_model_p2[0]
# ninth_model_valid_loss_p2 = ninth_model_p2[1]
# ninth_model_p3 = s1_p3['ninth_model']
# ninth_model_train_loss_p3 = ninth_model_p3[0]
# ninth_model_valid_loss_p3 = ninth_model_p3[1]
ninth_model_train_loss = merge_array([ninth_model_train_loss_p1])#,ninth_model_train_loss_p2,ninth_model_train_loss_p3])
ninth_model_valid_loss = merge_array([ninth_model_valid_loss_p1])#,ninth_model_valid_loss_p2,ninth_model_valid_loss_p3])
plt.figure()
plt.plot(ninth_model_train_loss)
plt.show()
plt.figure()
plt.plot(ninth_model_valid_loss)
plt.show()
plt.figure()
plt.plot(ninth_model_valid_loss[8000:10000])
plt.show()
training_result(ninth_model_valid_loss)
# Out:
# lowest loss is 0.8585861523946127 at epoch : 9577

# %%
#m11
m11_p1 = s2_p1['m11']
m11_train_loss_p1 = m11_p1[0]
m11_valid_loss_p1 = m11_p1[1]
# m11_p2 = s2_p2['m11']
# m11_train_loss_p2 = m11_p2[0]
# m11_valid_loss_p2 = m11_p2[1]
# m11_p3 = s2_p3['m11']
# m11_train_loss_p3 = m11_p3[0]
# m11_valid_loss_p3 = m11_p3[1]
m11_train_loss = merge_array([m11_train_loss_p1])#, m11_train_loss_p2,m11_train_loss_p3])
m11_valid_loss = merge_array([m11_valid_loss_p1])#, m11_valid_loss_p2,m11_valid_loss_p3])
plt.figure()
plt.plot(m11_train_loss)
plt.show()
plt.figure()
plt.plot(m11_valid_loss)
plt.show()
plt.figure()
plt.plot(m11_valid_loss[2000:3000])
plt.show()
training_result(m11_valid_loss)
# Out:
# lowest loss is 0.9093304872512817 at epoch : 1142

# %%
#m12
m12_p1 = s2_p1['m12']
m12_train_loss_p1 = m12_p1[0]
m12_valid_loss_p1 = m12_p1[1]
# m12_p2 = s2_p2['m12']
# m12_train_loss_p2 = m12_p2[0]
# m12_valid_loss_p2 = m12_p2[1]
# m12_p3 = s2_p3['m12']
# m12_train_loss_p3 = m12_p3[0]
# m12_valid_loss_p3 = m12_p3[1]
m12_train_loss = merge_array([m12_train_loss_p1])#, m12_train_loss_p2, m12_train_loss_p3])
m12_valid_loss = merge_array([m12_valid_loss_p1])#, m12_valid_loss_p2, m12_valid_loss_p3])
plt.figure()
plt.plot(m12_train_loss)
plt.show()
plt.figure()
plt.plot(m12_valid_loss)
plt.show()
plt.figure()
plt.plot(m12_valid_loss[1000:3000])
plt.show()
training_result(m12_valid_loss)
# Out:
# lowest loss is 0.7354538639386495 at epoch : 1277

# %%
#m13
m13_p1 = s2_p1['m13']
m13_train_loss_p1 = m13_p1[0]
m13_valid_loss_p1 = m13_p1[1]
# m13_p2 = s2_p2['m13']
# m13_train_loss_p2 = m13_p2[0]
# m13_valid_loss_p2 = m13_p2[1]
# m13_p3 = s2_p3['m13']
# m13_train_loss_p3 = m13_p3[0]
# m13_valid_loss_p3 = m13_p3[1]
m13_train_loss = merge_array([m13_train_loss_p1])#, m13_train_loss_p2, m13_train_loss_p3])
m13_valid_loss = merge_array([m13_valid_loss_p1])#, m13_valid_loss_p2, m13_valid_loss_p3])
plt.figure()
plt.plot(m13_train_loss)
plt.show()
plt.figure()
plt.plot(m13_valid_loss)
plt.show()
plt.figure()
plt.plot(m13_valid_loss[6000:10000])
plt.show()
training_result(m13_valid_loss)
# Out:
# lowest loss is 0.7242230425278345 at epoch : 7722

# %%
#m14
m14_p1 = s2_p1['m14']
m14_train_loss_p1 = m14_p1[0]
m14_valid_loss_p1 = m14_p1[1]
# m14_p2 = s2_p2['m14']
# m14_train_loss_p2 = m14_p2[0]
# m14_valid_loss_p2 = m14_p2[1]
# m14_p3 = s2_p3['m14']
# m14_train_loss_p3 = m14_p3[0]
# m14_valid_loss_p3 = m14_p3[1]
m14_train_loss = merge_array([m14_train_loss_p1])#, m14_train_loss_p2,m14_train_loss_p3])
m14_valid_loss = merge_array([m14_valid_loss_p1])#, m14_valid_loss_p2, m14_valid_loss_p3])
plt.figure()
plt.plot(m14_train_loss)
plt.show()
plt.figure()
plt.plot(m14_valid_loss)
plt.show()
plt.figure()
plt.plot(m14_valid_loss[100:1500])
plt.show()
training_result(m14_valid_loss)
# Out:
# lowest loss is 0.9423621495564779 at epoch : 548

# %%
#m15
m15_p1 = s2_p1['m15']
m15_train_loss_p1 = m15_p1[0]
m15_valid_loss_p1 = m15_p1[1]
# m15_p2 = s2_p2['m15']
# m15_train_loss_p2 = m15_p2[0]
# m15_valid_loss_p2 = m15_p2[1]
# m15_p3 = s2_p3['m15']
# m15_train_loss_p3 = m15_p3[0]
# m15_valid_loss_p3 = m15_p3[1]
m15_train_loss = merge_array([m15_train_loss_p1])#, m15_train_loss_p2,m15_train_loss_p3])
m15_valid_loss = merge_array([m15_valid_loss_p1])#, m15_valid_loss_p2,m15_valid_loss_p3])
plt.figure()
plt.plot(m15_train_loss)
plt.show()
plt.figure()
plt.plot(m15_valid_loss)
plt.show()
plt.figure()
plt.plot(m15_valid_loss[100:1000])
plt.show()
training_result(m15_valid_loss)
# Out:
# lowest loss is 0.7742895781993866 at epoch : 194

# %%
#m16
m16_p1 = s2_p1['m16']
m16_train_loss_p1 = m16_p1[0]
m16_valid_loss_p1 = m16_p1[1]
# m16_p2 = s2_p2['m16']
# m16_train_loss_p2 = m16_p2[0]
# m16_valid_loss_p2 = m16_p2[1]
# m16_p3 = s2_p3['m16']
# m16_train_loss_p3 = m16_p3[0]
# m16_valid_loss_p3 = m16_p3[1]
m16_train_loss = merge_array([m16_train_loss_p1])#, m16_train_loss_p2, m16_train_loss_p3])
m16_valid_loss = merge_array([m16_valid_loss_p1])#, m16_valid_loss_p2, m16_valid_loss_p3])
# plt.figure()
# plt.plot(m16_train_loss)
# plt.show()
plt.figure()
plt.plot(m16_valid_loss)
plt.show()
plt.figure()
plt.plot(m16_valid_loss[100:2000])
plt.show()
training_result(m16_valid_loss)
# Out:
# lowest loss is 0.7425097972154617 at epoch : 618

# %%
#m17
m17_p1 = s2_p1['m17']
m17_train_loss_p1 = m17_p1[0]
m17_valid_loss_p1 = m17_p1[1]
# m17_p2 = s2_p2['m17']
# m17_train_loss_p2 = m17_p2[0]
# m17_valid_loss_p2 = m17_p2[1]
# m17_p3 = s2_p3['m17']
# m17_train_loss_p3 = m17_p3[0]
# m17_valid_loss_p3 = m17_p3[1]
m17_train_loss = merge_array([m17_train_loss_p1])#, m17_train_loss_p2, m17_train_loss_p3 ])
m17_valid_loss = merge_array([m17_valid_loss_p1])#, m17_valid_loss_p2, m17_valid_loss_p3])
# plt.figure()
# plt.plot(m17_train_loss)
# plt.show()
plt.figure()
plt.plot(m17_valid_loss)
plt.show()
plt.figure()
plt.plot(m17_valid_loss[9000:10000])
plt.show()
training_result(m17_valid_loss)
# Out:
# lowest loss is 0.5582839002211889 at epoch : 9319

# %%
#m18
m18_p1 = s2_p1['m18']
m18_train_loss_p1 = m18_p1[0]
m18_valid_loss_p1 = m18_p1[1]
# m18_p2 = s2_p2['m18']
# m18_train_loss_p2 = m18_p2[0]
# m18_valid_loss_p2 = m18_p2[1]
# m18_p3 = s2_p3['m18']
# m18_train_loss_p3 = m18_p3[0]d
# m18_valid_loss_p3 = m18_p3[1]
m18_train_loss = merge_array([m18_train_loss_p1])#, m18_train_loss_p2,m18_train_loss_p3])
m18_valid_loss = merge_array([m18_valid_loss_p1])#, m18_valid_loss_p2, m18_valid_loss_p3])
plt.figure()
plt.plot(m18_train_loss)
plt.show()
plt.figure()
plt.plot(m18_valid_loss)
plt.show()
plt.figure()
plt.plot(m18_valid_loss[100:1400])
plt.show()
training_result(m18_valid_loss)
# Out:
# lowest loss is 0.7193944752216339 at epoch : 854

# %%
#m19
m19_p1 = s2_p1['m19']
m19_train_loss_p1 = m19_p1[0]
m19_valid_loss_p1 = m19_p1[1]
# m19_p2 = s2_p2['m19']
# m19_train_loss_p2 = m19_p2[0]
# m19_valid_loss_p2 = m19_p2[1]
# m19_p3 = s2_p3['m19']
# m19_train_loss_p3 = m19_p3[0]
# m19_valid_loss_p3 = m19_p3[1]
m19_train_loss = merge_array([m19_train_loss_p1])#, m19_train_loss_p2, m19_train_loss_p3])
m19_valid_loss = merge_array([m19_valid_loss_p1])#, m19_valid_loss_p2, m19_valid_loss_p3])
# plt.figure()
# plt.plot(m19_train_loss)
# plt.show()
plt.figure()
plt.plot(m19_valid_loss)
plt.show()
plt.figure()
plt.plot(m19_valid_loss[100:1000])
plt.show()
training_result(m19_valid_loss)
# Out:
# lowest loss is 0.7016235093275706 at epoch : 214

# %%
#m21
m21_p1 = s3_p1['m21']
m21_train_loss_p1 = m21_p1[0]
m21_valid_loss_p1 = m21_p1[1]
# m21_p2 = s3_p2['m21']
# m21_train_loss_p2 = m21_p2[0]
# m21_valid_loss_p2 = m21_p2[1]
# m21_p3 = s3_p3['m21']
# m21_train_loss_p3 = m21_p3[0]
# m21_valid_loss_p3 = m21_p3[1]
m21_train_loss = merge_array([m21_train_loss_p1])#, m21_train_loss_p2, m21_train_loss_p3])
m21_valid_loss = merge_array([m21_valid_loss_p1])#, m21_valid_loss_p2, m21_valid_loss_p3])
# plt.figure()
# plt.plot(m21_train_loss)
# plt.show()
plt.figure()
plt.plot(m21_valid_loss)
plt.show()
plt.figure()
plt.plot(m21_valid_loss[3500:4500])
plt.show()
training_result(m21_valid_loss)
# Out:
# lowest loss is 1.0141806602478027 at epoch : 3612

# %%
#m22
m22_p1 = s3_p1['m22']
m22_train_loss_p1 = m22_p1[0]
m22_valid_loss_p1 = m22_p1[1]
# m22_p2 = s3_p2['m22']
# m22_train_loss_p2 = m22_p2[0]
# m22_valid_loss_p2 = m22_p2[1]
# m22_p3 = s3_p3['m22']
# m22_train_loss_p3 = m22_p3[0]
# m22_valid_loss_p3 = m22_p3[1]
m22_train_loss = merge_array([m22_train_loss_p1])#, m22_train_loss_p2, m22_train_loss_p3])
m22_valid_loss = merge_array([m22_valid_loss_p1])#, m22_valid_loss_p2, m22_valid_loss_p3])
# plt.figure()
# plt.plot(m22_train_loss)
# plt.show()
plt.figure()
plt.plot(m22_valid_loss)
plt.show()
plt.figure()
plt.plot(m22_valid_loss[9000:10000])
plt.show()
training_result(m22_valid_loss)
# Out:
# lowest loss is 1.154470721880595 at epoch : 9031

# %%
#m23  # shoud continue to train
m23_p1 = s3_p1['m23']
m23_train_loss_p1 = m23_p1[0]
m23_valid_loss_p1 = m23_p1[1]
# m23_p2 = s3_p2['m23']
# m23_train_loss_p2 = m23_p2[0]
# m23_valid_loss_p2 = m23_p2[1]
# m23_p3 = s3_p3['m23']
# m23_train_loss_p3 = m23_p3[0]
# m23_valid_loss_p3 = m23_p3[1]
m23_train_loss = merge_array([m23_train_loss_p1])#, m23_train_loss_p2, m23_train_loss_p3])
m23_valid_loss = merge_array([m23_valid_loss_p1])#, m23_valid_loss_p2, m23_valid_loss_p3])
# plt.figure()
# plt.plot(m23_train_loss)
# plt.show()
plt.figure()
plt.plot(m23_valid_loss)
plt.show()
plt.figure()
plt.plot(m23_valid_loss[5000:7000])
plt.show()
training_result(m23_valid_loss)
# Out:
# lowest loss is 0.9422957201798757 at epoch : 6835

# %%
#m24
m24_p1 = s3_p1['m24']
m24_train_loss_p1 = m24_p1[0]
m24_valid_loss_p1 = m24_p1[1]
# m24_p2 = s3_p2['m24']
# m24_train_loss_p2 = m24_p2[0]
# m24_valid_loss_p2 = m24_p2[1]
# m24_p3 = s3_p3['m24']
# m24_train_loss_p3 = m24_p3[0]
# m24_valid_loss_p3 = m24_p3[1]
m24_train_loss = merge_array([m24_train_loss_p1])#, m24_train_loss_p2, m24_train_loss_p3])
m24_valid_loss = merge_array([m24_valid_loss_p1])#, m24_valid_loss_p2, m24_valid_loss_p3])
# plt.figure()
# plt.plot(m24_train_loss)
# plt.show()
plt.figure()
plt.plot(m24_valid_loss)
plt.show()
plt.figure()
plt.plot(m24_valid_loss[9000:10000])
plt.show()
training_result(m24_valid_loss)
# Out:
# lowest loss is 1.3953707714875538 at epoch : 9161

# %%
#m25
m25_p1 = s3_p1['m25']
m25_train_loss_p1 = m25_p1[0]
m25_valid_loss_p1 = m25_p1[1]
# m25_p2 = s3_p2['m25']
# m25_train_loss_p2 = m25_p2[0]
# m25_valid_loss_p2 = m25_p2[1]
# m25_p3 = s3_p3['m25']
# m25_train_loss_p3 = m25_p3[0]
# m25_valid_loss_p3 = m25_p3[1]
m25_train_loss = merge_array([m25_train_loss_p1])#, m25_train_loss_p2, m25_train_loss_p3])
m25_valid_loss = merge_array([m25_valid_loss_p1])#, m25_valid_loss_p2, m25_valid_loss_p3])
# plt.figure()
# plt.plot(m25_train_loss)
# plt.show()
plt.figure()
plt.plot(m25_valid_loss)
plt.show()
plt.figure()
plt.plot(m25_valid_loss[9000:10000])
plt.show()
training_result(m25_valid_loss)
# Out:
# lowest loss is 1.0593961477279663 at epoch : 9777

# %%
#m26
m26_p1 = s3_p1['m26']
m26_train_loss_p1 = m26_p1[0]
m26_valid_loss_p1 = m26_p1[1]
# m26_p2 = s3_p2['m26']
# m26_train_loss_p2 = m26_p2[0]
# m26_valid_loss_p2 = m26_p2[1]
# m26_p3 = s3_p3['m26']
# m26_train_loss_p3 = m26_p3[0]
# m26_valid_loss_p3 = m26_p3[1]
m26_train_loss = merge_array([m26_train_loss_p1])#, m26_train_loss_p2, m26_train_loss_p3])
m26_valid_loss = merge_array([m26_valid_loss_p1])#, m26_valid_loss_p2, m26_valid_loss_p3])
# plt.figure()
# plt.plot(m26_train_loss)
# plt.show()
plt.figure()
plt.plot(m26_valid_loss)
plt.show()
plt.figure()
plt.plot(m26_valid_loss[9000:10000])
plt.show()
training_result(m26_valid_loss)
# Out:
# lowest loss is 1.1045562128225963 at epoch : 9109

# %%
#m27
m27_p1 = s3_p1['m27']
m27_train_loss_p1 = m27_p1[0]
m27_valid_loss_p1 = m27_p1[1]
# m27_p2 = s3_p2['m27']
# m27_train_loss_p2 = m27_p2[0]
# m27_valid_loss_p2 = m27_p2[1]
# m27_p3 = s3_p3['m27']
# m27_train_loss_p3 = m27_p3[0]
# m27_valid_loss_p3 = m27_p3[1]
m27_train_loss = merge_array([m27_train_loss_p1])#, m27_train_loss_p2,m27_train_loss_p3])
m27_valid_loss = merge_array([m27_valid_loss_p1])#, m27_valid_loss_p2,m27_valid_loss_p3])
# plt.figure()
# plt.plot(m27_train_loss)
# plt.show()
plt.figure()
plt.plot(m27_valid_loss)
plt.show()
plt.figure()
plt.plot(m27_valid_loss[5000:6500])
plt.show()
training_result(m27_valid_loss)
# Out:
# lowest loss is 0.9161153237024943 at epoch : 5051

# %%
#m28
m28_p1 = s3_p1['m28']
m28_train_loss_p1 = m28_p1[0]
m28_valid_loss_p1 = m28_p1[1]
# m28_p2 = s3_p2['m28']
# m28_train_loss_p2 = m28_p2[0]
# m28_valid_loss_p2 = m28_p2[1]
# m28_p3 = s3_p3['m28']
# m28_train_loss_p3 = m28_p3[0]
# m28_valid_loss_p3 = m28_p3[1]
m28_train_loss = merge_array([m27_train_loss_p1])#, m28_train_loss_p2,m28_train_loss_p3])
m28_valid_loss = merge_array([m27_valid_loss_p1])#, m28_valid_loss_p2, m28_valid_loss_p3])
plt.figure()
plt.plot(m28_train_loss)
plt.show()
plt.figure()
plt.plot(m28_valid_loss)
plt.show()
plt.figure()
plt.plot(m28_valid_loss[4500:5500])
plt.show()
training_result(m28_valid_loss)
# Out:
# lowest loss is 0.9161153237024943 at epoch : 5051

# %%
#m29
m29_p1 = s3_p1['m29']
m29_train_loss_p1 = m29_p1[0]
m29_valid_loss_p1 = m29_p1[1]
# m29_p2 = s3_p2['m29']
# m29_train_loss_p2 = m29_p2[0]
# m29_valid_loss_p2 = m29_p2[1]
# m29_p3 = s3_p3['m29']
# m29_train_loss_p3 = m29_p3[0]
# m29_valid_loss_p3 = m29_p3[1]
m29_train_loss = merge_array([m29_train_loss_p1])#, m29_train_loss_p2,m29_train_loss_p3])
m29_valid_loss = merge_array([m29_valid_loss_p1])#, m29_valid_loss_p2, m29_valid_loss_p3])
plt.figure()
plt.plot(m29_train_loss)
plt.show()
plt.figure()
plt.plot(m29_valid_loss)
plt.show()
plt.figure()
plt.plot(m29_valid_loss[2000:5000])
plt.show()
training_result(m29_valid_loss)
# Out:
# lowest loss is 0.7031094854076704 at epoch : 2016

# %%
#m31
m31_p1 = s4_p1['m31']
m31_train_loss_p1 = m31_p1[0]
m31_valid_loss_p1 = m31_p1[1]
# m31_p2 = s4_p2['m31']
# m31_train_loss_p2 = m31_p2[0]
# m31_valid_loss_p2 = m31_p2[1]
m31_train_loss = merge_array([m31_train_loss_p1])#, m31_train_loss_p2])
m31_valid_loss = merge_array([m31_valid_loss_p1])#, m31_valid_loss_p2])
# plt.figure()
# plt.plot(m31_train_loss)
# plt.show()
plt.figure()
plt.plot(m31_valid_loss)
plt.show()
plt.figure()
plt.plot(m31_valid_loss[3000:4500])
plt.show()
training_result(m31_valid_loss)
# Out:
# lowest loss is 0.7895515163739523 at epoch : 3587

# %%
#m32
m32_p1 = s4_p1['m32']
m32_train_loss_p1 = m32_p1[0]
m32_valid_loss_p1 = m32_p1[1]
# m32_p2 = s4_p2['m32']
# m32_train_loss_p2 = m32_p2[0]
# m32_valid_loss_p2 = m32_p2[1]
# m32_p3 = s4_p3['m32']
# m32_train_loss_p3 = m32_p3[0]
# m32_valid_loss_p3 = m32_p3[1]
m32_train_loss = merge_array([m32_train_loss_p1])#, m32_train_loss_p2, m32_train_loss_p3])
m32_valid_loss = merge_array([m32_valid_loss_p1])#, m32_valid_loss_p2,m32_valid_loss_p3])
# plt.figure()
# plt.plot(m32_train_loss)
# plt.show()
plt.figure()
plt.plot(m32_valid_loss)
plt.show()
plt.figure()
plt.plot(m32_valid_loss[500:2000])
plt.show()
training_result(m32_valid_loss)
# Out:
# lowest loss is 0.952126701672872 at epoch : 925

# %%
#m33
m33_p1 = s4_p1['m33']
m33_train_loss_p1 = m33_p1[0]
m33_valid_loss_p1 = m33_p1[1]
# m33_p2 = s4_p2['m33']
# m33_train_loss_p2 = m33_p2[0]
# m33_valid_loss_p2 = m33_p2[1]
# m33_p3 = s4_p3['m33']
# m33_train_loss_p3 = m33_p3[0]
# m33_valid_loss_p3 = m33_p3[1]
m33_train_loss = merge_array([m33_train_loss_p1])#, m33_train_loss_p2,m33_train_loss_p3])
m33_valid_loss = merge_array([m33_valid_loss_p1])#, m33_valid_loss_p2,m33_valid_loss_p3])
# plt.figure()
# plt.plot(m33_train_loss)
# plt.show()
plt.figure()
plt.plot(m33_valid_loss)
plt.show()
plt.figure()
plt.plot(m33_valid_loss[100:2000])
plt.show()
training_result(m33_valid_loss)
# Out:
# lowest loss is 0.9511303504308065 at epoch : 253

# %%
#m34
m34_p1 = s4_p1['m34']
m34_train_loss_p1 = m34_p1[0]
m34_valid_loss_p1 = m34_p1[1]
# m34_p2 = s4_p2['m34']
# m34_train_loss_p2 = m34_p2[0]
# m34_valid_loss_p2 = m34_p2[1]
# m34_p3 = s4_p3['m34']
# m34_train_loss_p3 = m34_p3[0]
# m34_valid_loss_p3 = m34_p3[1]
m34_train_loss = merge_array([m34_train_loss_p1])#, m34_train_loss_p2,m34_train_loss_p3])
m34_valid_loss = merge_array([m34_valid_loss_p1])#, m34_valid_loss_p2,m34_valid_loss_p3])
# plt.figure()
# plt.plot(m34_train_loss)
# plt.show()
plt.figure()
plt.plot(m34_valid_loss[1500:3000])
plt.show()
training_result(m34_valid_loss)
# Out:
# lowest loss is 1.1584349473317463 at epoch : 1544

# %%
#m35
m35_p1 = s4_p1['m35']
m35_train_loss_p1 = m35_p1[0]
m35_valid_loss_p1 = m35_p1[1]
# m35_p2 = s4_p2['m35']
# m35_train_loss_p2 = m35_p2[0]
# m35_valid_loss_p2 = m35_p2[1]
# m35_p3 = s4_p3['m35']
# m35_train_loss_p3 = m35_p3[0]
# m35_valid_loss_p3 = m35_p3[1]
m35_train_loss = merge_array([m35_train_loss_p1])#, m35_train_loss_p2, m35_train_loss_p3])
m35_valid_loss = merge_array([m35_valid_loss_p1])#, m35_valid_loss_p2, m35_valid_loss_p3])
# plt.figure()
# plt.plot(m35_train_loss)
# plt.show()
plt.figure()
plt.plot(m35_valid_loss)
plt.show()
plt.figure()
plt.plot(m35_valid_loss[500:1500])
plt.show()
training_result(m35_valid_loss)
# Out:
# lowest loss is 0.9609115322430929 at epoch : 904

# %%
#m36
m36_p1 = s4_p1['m36']
m36_train_loss_p1 = m36_p1[0]
m36_valid_loss_p1 = m36_p1[1]
# m36_p2 = s4_p2['m36']
# m36_train_loss_p2 = m36_p2[0]
# m36_valid_loss_p2 = m36_p2[1]
# m36_p3 = s4_p3['m36']
# m36_train_loss_p3 = m36_p3[0]
# m36_valid_loss_p3 = m36_p3[1]
m36_train_loss = merge_array([m36_train_loss_p1])#, m36_train_loss_p2,m36_train_loss_p3])
m36_valid_loss = merge_array([m36_valid_loss_p1])#, m36_valid_loss_p2,m36_valid_loss_p3])
# plt.figure()
# plt.plot(m36_train_loss)
# plt.show()
plt.figure()
plt.plot(m36_valid_loss)
plt.show()
plt.figure()
plt.plot(m36_valid_loss[6000:9000])
plt.show()
training_result(m36_valid_loss)
# Out:
# lowest loss is 0.8377084036668142 at epoch : 6485

# %%
#m37
m37_p1 = s4_p1['m37']
m37_train_loss_p1 = m37_p1[0]
m37_valid_loss_p1 = m37_p1[1]
# m37_p2 = s4_p2['m37']
# m37_train_loss_p2 = m37_p2[0]
# m37_valid_loss_p2 = m37_p2[1]
# m37_p3 = s4_p3['m37']
# m37_train_loss_p3 = m37_p3[0]
# m37_valid_loss_p3 = m37_p3[1]
m37_train_loss = merge_array([m37_train_loss_p1])#, m37_train_loss_p2,m37_train_loss_p3])
m37_valid_loss = merge_array([m37_valid_loss_p1])#, m37_valid_loss_p2,m37_valid_loss_p3])
# plt.figure()
# plt.plot(m37_train_loss)
# plt.show()
plt.figure()
plt.plot(m37_valid_loss)
plt.show()
plt.figure()
plt.plot(m37_valid_loss[4000:5500])
plt.show()
training_result(m37_valid_loss)
# Out:
# lowest loss is 0.6364699155092239 at epoch : 4933

# %%
#m38
m38_p1 = s4_p1['m38']
m38_train_loss_p1 = m38_p1[0]
m38_valid_loss_p1 = m38_p1[1]
# m38_p2 = s4_p2['m38']
# m38_train_loss_p2 = m38_p2[0]
# m38_valid_loss_p2 = m38_p2[1]
# m38_p3 = s4_p3['m38']
# m38_train_loss_p3 = m38_p3[0]
# m38_valid_loss_p3 = m38_p3[1]
m38_train_loss = merge_array([m38_train_loss_p1])#, m38_train_loss_p2, m38_train_loss_p3])
m38_valid_loss = merge_array([m38_valid_loss_p1])#, m38_valid_loss_p2, m38_valid_loss_p3])
# plt.figure()
# plt.plot(m38_train_loss)
# plt.show()
plt.figure()
plt.plot(m38_valid_loss)
plt.show()
plt.figure()
plt.plot(m38_valid_loss[6000:8000])
plt.show()
training_result(m38_valid_loss)
# Out:
# lowest loss is 0.847816601395607 at epoch : 6731

# %%
#m39
m39_p1 = s4_p1['m39']
m39_train_loss_p1 = m39_p1[0]
m39_valid_loss_p1 = m39_p1[1]
# m39_p2 = s4_p2['m39']
# m39_train_loss_p2 = m39_p2[0]
# m39_valid_loss_p2 = m39_p2[1]
# m39_p3 = s4_p3['m39']
# m39_train_loss_p3 = m39_p3[0]
# m39_valid_loss_p3 = m39_p3[1]
m39_train_loss = merge_array([m39_train_loss_p1])#, m39_train_loss_p2,m39_train_loss_p3])
m39_valid_loss = merge_array([m39_valid_loss_p1])#, m39_valid_loss_p2, m39_valid_loss_p3])
# plt.figure()
# plt.plot(m39_train_loss)
# plt.show()
plt.figure()
plt.plot(m39_valid_loss)
plt.show()
plt.figure()
plt.plot(m39_valid_loss[200:2500])
plt.show()
training_result(m39_valid_loss)
# Out:
# lowest loss is 0.6137360334396362 at epoch : 412
